# %% [markdown]
# <a href="https://colab.research.google.com/github/gunkwak/class_bigdata/blob/main/%EA%B3%BD%EA%B1%B45%EA%B0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 5강과제

# %% [markdown]
# 8주차

# %%
import pandas as pd

# %%
data = {'age': [22, 35, 57, 84], 'name': ['민우', '현식', '두팔', '춘배'], 'height': [178.4, 168.3, 178.5, 162.3] }

# %%
x = pd.DataFrame(data, columns = ['name', 'age', 'height'])
x
# Out:
#   name  age  height
# 0   민우   22   178.4
# 1   현식   35   168.3
# 2   두팔   57   178.5
# 3   춘배   84   162.3

# %%
x.loc[4]=['덕팔', 78, 158.3]
x
# Out:
#   name  age  height
# 0   민우   22   178.4
# 1   현식   35   168.3
# 2   두팔   57   178.5
# 3   춘배   84   162.3
# 4   덕팔   78   158.3

# %%
y = pd.DataFrame({'age': [26], 'name': ['서학'], 'height': 170. }, columns=['name', 'age', 'height'])
y
# Out:
#   name  age  height
# 0   서학   26   170.0

# %%
result = x.append(y)

# %%
result
# Out:
#   name  age  height
# 0   민우   22   178.4
# 1   현식   35   168.3
# 2   두팔   57   178.5
# 3   춘배   84   162.3
# 4   덕팔   78   158.3
# 0   서학   26   170.0

# %%
result=x.append(y, ignore_index=True)
result
# Out:
#   name  age  height
# 0   민우   22   178.4
# 1   현식   35   168.3
# 2   두팔   57   178.5
# 3   춘배   84   162.3
# 4   덕팔   78   158.3
# 5   서학   26   170.0

# %%
x = x.append(y, ignore_index=True)
x
# Out:
#   name  age  height
# 0   민우   22   178.4
# 1   현식   35   168.3
# 2   두팔   57   178.5
# 3   춘배   84   162.3
# 4   덕팔   78   158.3
# 5   서학   26   170.0

# %%
result = pd.concat([x,y], ignore_index=True)
result
# Out:
#   name  age  height
# 0   민우   22   178.4
# 1   현식   35   168.3
# 2   두팔   57   178.5
# 3   춘배   84   162.3
# 4   덕팔   78   158.3
# 5   서학   26   170.0
# 6   서학   26   170.0

# %%
import numpy as np

# %%
df=pd.DataFrame(np.random.randn(5,5))

# %%
df.columns=['A','B','C','D','E']
df.iloc[1,1]=np.nan
df.iloc[2,2]=np.nan
df
# Out:
#           A         B         C         D         E
# 0  1.007027  0.463225 -0.762289 -1.267530  0.217270
# 1 -1.416157       NaN -1.343243 -0.999830 -0.535775
# 2  0.171816  0.878959       NaN -1.761908  0.709759
# 3 -0.388478 -0.904287  1.130931 -0.479183  0.849088
# 4  2.376966 -0.995485  3.027165  0.081415  1.694847

# %%
df.isnull()
# Out:
#        A      B      C      D      E
# 0  False  False  False  False  False
# 1  False   True  False  False  False
# 2  False  False   True  False  False
# 3  False  False  False  False  False
# 4  False  False  False  False  False

# %%
df['A'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: A, dtype: bool

# %%
df['D'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: D, dtype: bool

# %%
df['E'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: E, dtype: bool

# %%
df[df['B'].isnull()]
# Out:
#           A   B         C        D         E
# 1 -1.416157 NaN -1.343243 -0.99983 -0.535775

# %%
df.isnull().sum()
# Out:
# A    0
# B    1
# C    1
# D    0
# E    0
# dtype: int64

# %%
df['B'].isnull().sum()
# Out:
# 1

# %%
df.dropna()
# Out:
#           A         B         C         D         E
# 0  1.007027  0.463225 -0.762289 -1.267530  0.217270
# 3 -0.388478 -0.904287  1.130931 -0.479183  0.849088
# 4  2.376966 -0.995485  3.027165  0.081415  1.694847

# %%
df.dropna(inplace=True)
df
# Out:
#           A         B         C         D         E
# 0  1.007027  0.463225 -0.762289 -1.267530  0.217270
# 3 -0.388478 -0.904287  1.130931 -0.479183  0.849088
# 4  2.376966 -0.995485  3.027165  0.081415  1.694847

# %%
df.dropna(subset=['B'], axis=0, inplace=True)
df
# Out:
#           A         B         C         D         E
# 0  1.007027  0.463225 -0.762289 -1.267530  0.217270
# 3 -0.388478 -0.904287  1.130931 -0.479183  0.849088
# 4  2.376966 -0.995485  3.027165  0.081415  1.694847

# %%
df.dropna(subset=['B'], axis=0, inplace=True)
df
# Out:
#           A         B         C         D         E
# 0  1.007027  0.463225 -0.762289 -1.267530  0.217270
# 3 -0.388478 -0.904287  1.130931 -0.479183  0.849088
# 4  2.376966 -0.995485  3.027165  0.081415  1.694847

# %%
df.dropna(axis=1, inplace=True)
df
# Out:
#           A         B         C         D         E
# 0  1.007027  0.463225 -0.762289 -1.267530  0.217270
# 3 -0.388478 -0.904287  1.130931 -0.479183  0.849088
# 4  2.376966 -0.995485  3.027165  0.081415  1.694847

# %%
df.dropna(subset=[0,1], axis=1, inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-154-1c77de87f85c> in <module>()
# ----> 1 df.dropna(subset=[0,1], axis=1, inplace=True)
#       2 df
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    5951             check = indices == -1
#    5952             if check.any():
# -> 5953                 raise KeyError(list(np.compress(check, subset)))
#    5954             agg_obj = self.take(indices, axis=agg_axis)
#    5955
#
# KeyError: [1]

# %%
robots = [[24,23680], [35, np.nan], [46, 47350], [27,np.nan]]
data = pd.DataFrame(robots, columns=['max_spped','price'])
data
# Out:
#    max_spped    price
# 0         24  23680.0
# 1         35      NaN
# 2         46  47350.0
# 3         27      NaN

# %%
data.replace(np.nan, 0, inplace=True)
data
# Out:
#    max_spped    price
# 0         24  23680.0
# 1         35      0.0
# 2         46  47350.0
# 3         27      0.0

# %%
mean = data['price'].mean()
data.replace(np.nan, mean, inplace=True)
data
# Out:
#    max_spped    price
# 0         24  23680.0
# 1         35      0.0
# 2         46  47350.0
# 3         27      0.0

# %%
mean = data['price'].mean()
data.replace(np.nan, mean)
data
# Out:
#    max_spped    price
# 0         24  23680.0
# 1         35      0.0
# 2         46  47350.0
# 3         27      0.0

# %%
import seaborn as sns

# %%
iris = sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
vals = iris['sepal_length'].values

# %%
import matplotlib.pyplot as plt

# %%
sns.kdeplot(vals)

# %%
plt.title("kdeplot for sepal length")
plt.show()

# %%
vals = iris['petal_length'].values
sns.kdeplot(vals)

# %%
plt.title("kdeplot for petal length")
plt.show()

# %%
vals =iris['petal_length'].values
sns.displot(vals, kde=True, rug=True)

# %%
plt.title("distplot for petal length")
plt.show()

# %%
sns.displot(vals, kde=True, rug=True)
plt.title("displot for petal length")
plt.show()

# %%
import seaborn as sns

# %%
sns.displot(vals, kde=True)
plt.title("hisplot for petal length")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %% [markdown]
# 9주차

# %%
titanic = sns.load_dataset("titanic") 
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.countplot(x="adult_male", data=titanic)
plt.show()

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(x="day", data=tips)
plt.show()

# %%
sns.jointplot(x='sepal_length', y='sepal_width', data=iris, kind='scatter')
plt.show()

# %%
sns.jointplot(x='sepal_length', y='sepal_width', data=iris, hue='species', kind='kde')
plt.show()

# %%
sns.pairplot(iris)
plt.show()

# %%
sns.pairplot(iris, hue='species', markers=['o','s','d'])
plt.show()

# %%
titanic_size = titanic.pivot_table(index="class", columns="sex", aggfunc="size")
titanic_size
# Out:
# sex     female  male
# class
# First       94   122
# Second      76   108
# Third      144   347

# %%
sns.heatmap(titanic_size)
plt.title("Heatmap")
plt.show()

# %%
sns.heatmap(titanic_size, annot=True)
plt.title("Heatmap")
plt.show()

# %%
sns.heatmap(titanic_size, annot=True, fmt='d')
plt.title("Heatmap")
plt.show()

# %%
sns.heatmap(titanic_size, cmap=sns.color_palette("PuBu"), annot=True, fmt='d')
plt.title("Heatmap")
plt.show()

# %%
sns.barplot(x="day", y="total_bill", data=tips)
plt.title("Tips on each day")
plt.show()

# %%
sns.barplot(x='total_bill', y='day', data=tips)
plt.title('Tips on each day')
plt.show()

# %%
sns.stripplot(x='day', y='total_bill', data=tips, jitter=True)
plt.title('Tips on each day')
plt.show()

# %%
sns.stripplot(x='day', y='total_bill', data=tips, jitter=False)
plt.title('Tips on each day')
plt.show()

# %%
sns.swarmplot(x='day', y='total_bill', data=tips)
plt.title('Tips on each day')
plt.show()

# %%
sns.violinplot(x='day', y='total_bill', data=tips)
plt.title('tips on each day')
plt.show()

# %%
sns.barplot(x='day', y='total_bill', hue='sex', data=tips)
plt.title('Tips on each day with hue=sex')
plt.show()

# %%
sns.barplot(x='day', y='total_bill', hue='time', data=tips)
plt.title('Tips on each day with hue=time')
plt.show()

# %%
sns.stripplot(x='day', y='total_bill', hue='sex', data=tips)
plt.title('tips on each day with hue=sex')
plt.show()

# %%
sns.swarmplot(x='day', y='total_bill', hue='sex', data=tips)
plt.title('tips on each day with hue=sex')
plt.show()

# %%
sns.violinplot(x='day', y='total_bill', hue='sex', data=tips)
plt.title('tips on each day with hue=sex')
plt.show()

# %%
sns.violinplot(x='day', y='total_bill', hue='sex', data=tips, split=True)
plt.title('Tips on each day with option hue=sex and split=True')
plt.show()

# %%
sns.stripplot(x='day', y='total_bill', hue='sex', data=tips, dodge=True)
plt.title('Tips on each day with option hue=sex and dodge=True')
plt.show()

# %%
sns.catplot(x="age", y="sex", hue="survived", row="class", data=titanic, kind="violin", split=True, height=2, aspect=4)
plt.title("Catplot of titanic with hue=survived")
plt.show()

# %%
plt.title("violinplot and swarmplot")
sns.violinplot(x='day', y='total_bill', data=tips)
sns.swarmplot(x='day', y='total_bill', data=tips, color='0.9')
plt.show()
